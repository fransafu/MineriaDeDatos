# %%
# -*- coding: utf-8 -*-

# Importar librerias
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import seaborn as sns
from matplotlib import rcParams

# Configuraciones
# %matplotlib inline 
# %pylab inline 

# Lectura de datos de peliculas
# movieTitles = pd.read_json('./netflixData/movieTitles.json', orient='columns')

# Mostrar Tabla de datos para datos de peliculas
# movieTitles.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Lectura de datos de entrenamiento
##trainingSet = pd.read_csv("./netflixData/training_set.csv", sep=',', 
##                  names = ["ID_MOVIE", "ID_USUARIO", "RANKING", "DATE"])
trainingSet = pd.read_csv("/home/fransafu/UTEM/Respaldo_merge_data/final_training_set.csv", sep=',', 
                  names = ["ID_PELICULA", "ID_USUARIO", "RANKING"], usecols=[0,1,2])

# Mostrar Tabla de datos para datos de entrenamientos
trainingSet.head()
# Out:
#    ID_PELICULA  ID_USUARIO  RANKING
# 0            1     1488844        3
# 1            1      822109        5
# 2            1      885013        4
# 3            1       30878        4
# 4            1      823519        3

# %%
# Lectura de datos de entrenamiento
##trainingSet = pd.read_csv("./netflixData/training_set.csv", sep=',', 
##                  names = ["ID_MOVIE", "ID_USUARIO", "RANKING", "DATE"])
movieData = pd.read_csv("./pyMongo_DataMining/peliculas_info3.csv", sep='#')

# Mostrar Tabla de datos para datos de entrenamientos
movieData.head()
# Out:
#    ACTOR_ID         ACTOR_NOMBRE  ACTOR_GENERO   DIRECTOR_NOMBRE  \
# 0     83291  Pierre de Lespinois             0  Christian Slater
# 1    567257          Paul Heyman             0       Donna Adamo
# 2     89914       Elliott Nugent             2          Bob Hope
# 3     79469        Dwight Hemion             0      Neil Diamond
# 4      5045         Dan O'Bannon             2      Peter Weller
#
#    DIRECTOR_GENERO  DIRECTOR_ID  DIRECTOR_POPULARIDAD  TIEMPO  VOTO_PROMEDIO  \
# 0                2         2224              2.433044     194            7.0
# 1                0       590956              0.000002     170            6.3
# 2                2        82388              0.666791      87            6.6
# 3                2        69669              0.008334      60            0.0
# 4                2        27811              2.996912     108            6.1
#
#    PRESUPUESTO       ...        VOTO_CONTADOR  \
# 0            0       ...                  1.0
# 1            0       ...                  3.0
# 2            0       ...                 13.0
# 3            0       ...                  0.0
# 4     20000000       ...                156.0
#
#                              TITULO ID_DETALLE   INGRESOS  GENERO  ANIO  \
# 0                   Dinosaur Planet     194423        0.0      99  2003
# 1       WWE: The Rise & Fall of ECW      33209        0.0      99  2004
# 2              My Favorite Brunette      18649        0.0      35  1947
# 3  Neil Diamond: Greatest Hits Live      17673        0.0      99  1988
# 4                         Screamers       9102  5781885.0      27  1996
#
#    ID_PELICULA  ID_EXTERNO  POPULARIDAD  RATING_PROMEDIO
# 0            1      194423     1.115168         3.749543
# 1            5       33209     1.083446         3.919298
# 2           12       18649     1.854692         3.417582
# 3           15       17673     1.082002         3.286207
# 4           16        9102    16.052319         3.098555
#
# [5 rows x 24 columns]

# %%
mergeDataInfo = pd.merge(movieData, trainingSet, on='ID_PELICULA')
mergeDataInfo.head()
# Out:
#    ACTOR_ID         ACTOR_NOMBRE  ACTOR_GENERO   DIRECTOR_NOMBRE  \
# 0     83291  Pierre de Lespinois             0  Christian Slater
# 1     83291  Pierre de Lespinois             0  Christian Slater
# 2     83291  Pierre de Lespinois             0  Christian Slater
# 3     83291  Pierre de Lespinois             0  Christian Slater
# 4     83291  Pierre de Lespinois             0  Christian Slater
#
#    DIRECTOR_GENERO  DIRECTOR_ID  DIRECTOR_POPULARIDAD  TIEMPO  VOTO_PROMEDIO  \
# 0                2         2224              2.433044     194            7.0
# 1                2         2224              2.433044     194            7.0
# 2                2         2224              2.433044     194            7.0
# 3                2         2224              2.433044     194            7.0
# 4                2         2224              2.433044     194            7.0
#
#    PRESUPUESTO   ...    ID_DETALLE  INGRESOS GENERO  ANIO  ID_PELICULA  \
# 0            0   ...        194423       0.0     99  2003            1
# 1            0   ...        194423       0.0     99  2003            1
# 2            0   ...        194423       0.0     99  2003            1
# 3            0   ...        194423       0.0     99  2003            1
# 4            0   ...        194423       0.0     99  2003            1
#
#   ID_EXTERNO  POPULARIDAD  RATING_PROMEDIO  ID_USUARIO  RANKING
# 0     194423     1.115168         3.749543     1488844        3
# 1     194423     1.115168         3.749543      822109        5
# 2     194423     1.115168         3.749543      885013        4
# 3     194423     1.115168         3.749543       30878        4
# 4     194423     1.115168         3.749543      823519        3
#
# [5 rows x 26 columns]

# %%
# To csv
mergeDataInfo.to_csv("./merge.csv", sep='#', encoding='utf-8', index=False)
